# %% [markdown]
# ### TPC4: Aplicação para manipulação de listas de inteiros
# - Crie uma aplicação em Python que coloca no monitor o seguinte menu:
#     * (1) Criar Lista
#     * (2) Ler Lista
#     * (3) Soma
#     * (4) Média
#     * (5) Maior
#     * (6) Menor
#     * (7) estaOrdenada por ordem crescente
#     * (8) estaOrdenada por ordem decrescente
#     * (9) Procura um elemento
#     * (0) Sair
# - O utilizador irá escolher uma das opções introduzindo o número correspondente;
# - Se a opção não for sair, a aplicação executa a operação pretendida, apresenta o resultado e a seguir apresenta de novo o menu;
# - Se a opção for sair, a aplicação termina colocando uma mensagem no monitor.
#
# * No desenvolvimento da aplicação deverá ter em atenção o seguinte:
#     - A aplicação terá uma variável interna para guardar uma lista de números;
#     - Na opção 1, deverá ser criada uma lista de números aleatórios entre 1 e 100 que será guardada na variável interna;
#     - Na opção 2, deverá ser criada uma lista com números introduzidos pelo utilizador, que será guardada na variável interna;
#     - Nestas primeiras opções, se a variável interna já tiver uma lista, esta será sobreposta/apagada pela nova lista;
#     - Na opção 3, será calculada a soma dos elementos na lista no momento;
#     - Na opção 4, será calculada a média dos elementos na lista no momento;
#     - Na opção 5, será calculado o maior elemento da lista no momento;
#     - Na opção 6, será calculado o menor elemento da lista no momento;
#     - Na opção 7, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem crescente;
#     - Na opção 8, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem decrescente;
#     - Na opção 9, a aplicação irá procurar um elemento na lista, se o encontrar deverá devolver a sua posição, devolverá -1 se o elemento não estiver na lista;
#     - Se o utilizador selecionar a opção 0, a aplicação deverá terminar mostrando a lista que está nesse momento guardada.

# %%
Menu = ("Menu:\n(1) Criar Lista\n(2) Ler Lista\n(3) Soma\n(4) Média\n(5) Maior\n(6) Menor\n(7) está ordenada por ordem crescente\n(8) está ordenada por ordem decrescente\n(9) Procura um elemento\n(0) Sair")
print (Menu)
opção = input("Escolha uma opção, introduzindo o respetivo número.")
from random import randint
lista = []

while opção != "0":
    if opção == "1":
        lista.clear()
        tam = len(lista)
        tam = int(input("Introduza o número de elementos que deseja que a lista tenha."))
        while tam > 0:
            lista.append(randint(1,100))
            tam = tam - 1
        print ("A lista é " + str(lista) + ".")
        print (Menu)
    elif opção == "2":
        lista.clear()
        tam = len(lista)
        tam = int(input("Introduza o número de elementos que deseja que a lista tenha."))
        while tam > 0:
            e = input("Introduza " + str(tam) + " números.")
            lista.append (int(e))
            tam = tam - 1
        print("A lista é: " + str(lista) + ".")
        print (Menu)
    elif opção == "3":
        soma = 0
        for e in lista:
            soma = soma + e 
        print ("A soma dos elementos na lista é " + str(soma) + ".")
        print (Menu)
    elif opção == "4":
        soma = 0
        for e in lista:
            soma = soma + e
            média = soma/len(lista)
        print ("A média dos elementos na lista é " + str(média) + ".")
        print (Menu)
    elif opção == "5":
        maior = 0
        for e in lista:
            if e > maior:
                maior = e
        print ("O maior elemento da lista é " + str(maior) + ".")
        print (Menu)
    elif opção == "6":
        menor = 101
        for e in lista:
            if e < menor:
                menor = e
        print ("O menor elemento da lista é " + str(menor) + ".")
        print (Menu)
    elif opção == "7":
        tam = len(lista)
        while tam > 0:
            for n in range(0, tam - 1):
                if lista[n] > lista[n + 1]:
                    resposta = "Não."
                else:
                    resposta = "Sim."
            tam = tam - 1
        print("A lista está ordenada por ordem crescente? Resposta: " + str(resposta))
        print (Menu)
    elif opção == "8":
        tam = len(lista)
        while tam > 0:
            for n in range(0, tam - 1):
                if lista[n] < lista[n + 1]:
                    resposta = "Não."
                else:
                    resposta = "Sim."
            tam = tam - 1
        print ("A lista está ordenada por ordem decrescente? Resposta: " + str(resposta))
        print (Menu)
    elif opção == "9":
        e = int(input("Qual o elemento que deseja encontrar na lista?"))
        if e in lista:
            n = lista.index(e)
        elif e not in lista:
            n = -1
        print("A posição do elemento na lista é " + str(n))
    opção = input("Escolha uma opção, introduzindo o respetivo número.")   
print ("Encerrou a aplicação. A sua lista final é: " + str(lista) + ".")
# Out:
# Menu:
# (1) Criar Lista
# (2) Ler Lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) está ordenada por ordem crescente
# (8) está ordenada por ordem decrescente
# (9) Procura um elemento
# (0) Sair
# A lista é: [30, 45, 67, 80].
# Menu:
# (1) Criar Lista
# (2) Ler Lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) está ordenada por ordem crescente
# (8) está ordenada por ordem decrescente
# (9) Procura um elemento
# (0) Sair
# A lista está ordenada por ordem crescente? Resposta: Sim.
# Menu:
# (1) Criar Lista
# (2) Ler Lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) está ordenada por ordem crescente
# (8) está ordenada por ordem decrescente
# (9) Procura um elemento
# (0) Sair
# O maior elemento da lista é 80.
# Menu:
# (1) Criar Lista
# (2) Ler Lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) está ordenada por ordem crescente
# (8) está ordenada por ordem decrescente
# (9) Procura um elemento
# (0) Sair
# Encerrou a aplicação. A sua lista final é: [30, 45, 67, 80].
