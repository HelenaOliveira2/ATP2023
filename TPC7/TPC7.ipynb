# %% [markdown]
# ### TPC7: Construir uma aplicação para manipular polinómios
#
# Depois da aula da semana passada, já tens algumas funções desenvolvidas que te irão ajudar a construir a aplicação que se descreve a seguir.
#
# * Aquecimento: Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula
#     - `x^7 - 3.7x^4 + 5x^3 - 88`
#     - `2x^2 + 17`
#     - `7x^4 + 6x^3 - x^2 + 43`
#     - `x^4`
#     - `x^2`
#     - `x^3`
#
# * Desenvolve as seguintes funcionalidades que não foram trabalhadas na aula:
#     1. Define uma função que dado um polinómio calcula a sua derivada;
#     2. Define uma função que recebe dois polinómios `p1` e `p2` e calcula um novo polinómio correspondente à soma de `p1` e `p2`;
#     3. Define uma função que recebe um polinómio e o desenha num gráfico.
#
# * Num ficheiro Python, cria uma aplicação para manipular polinómios com as seguintes operações:
#     1. Criar um polinómio interativamente;
#     2. Ler uma lista de polinómios de um ficheiro;
#     3. Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um;
#     4. Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio);
#     5. Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau;
#     6. Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem;
#     7. Derivada: mostra uma tabela com os polinómios e as respetivas derivadas;
#     8. Somar dois polinómios: indicando os seus números de ordem;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação

# %%
p1 = [(1,7), (-3.7,4), (5,3), (88,0)]
p2 = [(2,2), (17,0)]
p3 = [(7,4), (6,3), (-1,2), (43,0)]
p4 = [(1,4)]
p5 = [(1,2)]
p6 = [(1,3)]
listap = [p1,p2,p3,p4,p5,p6]
def guardar_polinomios(listap, fnome):
    file = open ("polinomios.txt", "w")
    for p in listap:
        for termo in p:
            coeficiente = termo[0]
            grau = termo[1]
            file.write(str(coeficiente) + "," + str(grau) + "#")
        file.write("\n")
    file.close()
guardar_polinomios(listap,"polinomios.txt")

# %%
#1
def Criar_Polinomio():
    polinomio = []
    grau = int(input ("Insira o grau do polinomio"))
    i = 1
    while grau >= 0:
        coeficiente = int(input ("Insira o coeficiente do polinómio " + str(i)))
        if coeficiente != 0:
            termo = (coeficiente, grau)
            polinomio.append(termo)
        grau = grau - 1
        i = i + 1
    return polinomio
def derivarPolinomio(polinomio):
    derivada = [] 
    for coeficiente,grau in polinomio:
        if grau !=0:
            grau2 = grau - 1 
            derivada.append((coeficiente*grau, grau2))
    return derivada
print (derivarPolinomio(Criar_Polinomio()))
# Out:
# [(6, 1), (2, 0)]

# %%
#2
def Criar_Polinomio1():
    p7 = []
    grau = int(input ("Insira o grau do p7"))
    i = 1
    while grau >= 0:
        coeficiente = int(input ("Insira o coeficiente do p7 " + str(i)))
        if coeficiente != 0:
            termo = (coeficiente, grau)
            p7.append(termo)
        grau = grau - 1
        i = i + 1
    return p7
def Criar_Polinomio2():
    p8 = []
    grau = int(input ("Insira o grau do p8"))
    i = 1
    while grau >= 0:
        coeficiente = int(input ("Insira o coeficiente do p8 " + str(i)))
        if coeficiente != 0:
            termo = (coeficiente, grau)
            p8.append(termo)
        grau = grau - 1
        i = i + 1
    return p8
def somarPolinomios(p7,p8):
    soma = []
    m = 0
    n = 0
    while m < len(p7) and n < len(p8):
        coeficiente1, grau1 = p7[m]
        coeficiente2, grau2 = p8[n]
        if grau1 == grau2:
            soma.append((coeficiente1 + coeficiente2, grau1))
            m = m + 1
            n = n + 1
        elif grau1 > grau2:
            soma.append((coeficiente1, grau1))
            m = m + 1
        else:
            soma.append((coeficiente2, grau2))
            n = n + 1
    return soma
print (somarPolinomios(Criar_Polinomio1(), Criar_Polinomio2()))
# Out:
# [(2, 3), (6, 2), (3, 1), (6, 0)]

# %%
#3
def Criar_Polinomio():
    polinomio = []
    grau = int(input ("Insira o grau do polinomio"))
    i = 1
    while grau >= 0:
        coeficiente = int(input ("Insira o coeficiente do polinómio " + str(i)))
        if coeficiente != 0:
            termo = (coeficiente, grau)
            polinomio.append(termo)
        grau = grau - 1
        i = i + 1
    return polinomio

def pot (a,b):
    res = 1
    while b > 0:
        res = res * a
        b = b - 1
    return res 
def calc_Polinomio(p, x):
    res = 0
    for termo in p:
        coeficiente = termo[0]
        grau = termo[1]
        #coeficiente, grau = termo
        res = res + coeficiente * pot(x,grau)
    return res

import matplotlib.pyplot as plt
def grafico_polinomio(p):
    abcissas = []
    ordenadas = []
    for x in range (0,10):
        abcissas.append(x)
        y = calc_Polinomio(p,x)
        ordenadas.append(y)
    plt.plot(abcissas, ordenadas, color = "green")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Gráfico do polinómio " + str(p))
    plt.show()
print(grafico_polinomio(Criar_Polinomio()))
# Out:
# None

# %%
#1
def Criar_Polinomio():
    polinomio = []
    grau = int(input ("Insira o grau do polinomio"))
    i = 1
    while grau >= 0:
        coeficiente = int(input ("Insira o coeficiente do polinómio " + str(i)))
        if coeficiente != 0:
            termo = (coeficiente, grau)
            polinomio.append(termo)
        grau = grau - 1
        i = i + 1
    print (polinomio)
    listap.append(polinomio)
    guardar_polinomios (listap,"polinómios.txt")

#2
def Ler_Ficheiro(fnome):
    file = open (fnome, "r")
    linhas = file.readlines()
    registo = []
    for linha in linhas:
        polinomio = []
        termo = linha.split("#")
        termo.remove("\n")
        for t in termo:
            monomio = t.split(",")
            monomio = (float(monomio[0]),int(monomio[1]))
            polinomio.append(monomio)
        registo.append(polinomio)
    file.close()
    return registo

#3
def listarPolinomios(fnome):
    file = open(fnome, "r")
    print ("___Ordem ___|______________ Polinomio_____________________")
    ordem = 1
    linhas = file.readlines()
    for linha in linhas:
        polinomio = []
        termo = linha.split("#")
        termo.remove ("\n") 
        for t in termo:
            monomio = t.split(",")
            monomio = (float(monomio[0]),int(monomio[1]))
            polinomio.append(monomio)
        print ("    ", str(ordem), "     |   ", polinomio) 
        ordem = ordem + 1
    file.close()

#4
def pot (a,b):
    res = 1
    while b > 0:
        res = res * a
        b = b - 1
    return res 
def calc_Polinomio(polinomio, x):
    res = 0
    for termo in polinomio:
        coeficiente = termo[0]
        grau = termo[1]
        #coeficiente, grau = termo
        res = res + coeficiente * pot(x,grau)
    return res

#5
def listarPolinomiosGrau(fnome):
    file = open(fnome, "r")
    print ("__Ordem___|___Grau___|_________Polinómio__________________________")
    linhas = file.readlines()
    ordem = 1
    maior = 0
    for linha in linhas:
        polinomio = []
        termo = linha.split("#")
        termo.remove ("\n") 
        maior = 0
        for t in termo:
            monomio = t.split(",")
            coeficiente, grau = monomio
            monomio = (float(monomio[0]),int(monomio[1]))
            polinomio.append(monomio)
            if int(grau) > int(maior):
                maior = grau
        print ("   ", ordem, "    |    ", maior, "   |   ", polinomio)
        ordem = ordem + 1
    file.close()

#6
def maior_grauPol(fnome):
    print ("__________Polinomio de maior grau____________|____Ordem___")
    file = open (fnome, "r")
    linhas = file.readlines()
    ordem = 0
    maior = 0
    x = 0
    for linha in linhas:
        termo = linha.split("#")
        termo.remove ("\n") 
        ordem = ordem + 1
        for t in termo:
            monomio = t.split(",")  
            coeficiente, grau = monomio 
            monomio = (float(monomio[0]),int(monomio[1]))
            if int(grau) > int(maior):
                maior = grau
                n = x
        x = x + 1
    print (Ler_Ficheiro("polinomios.txt")[n], "  |   ", ordem )
    file.close()


#7
def derivada_Polinomio(fnome):
    print ("__________Polinomio___________________|_____________Derivada___________")
    file = open (fnome, "r")
    linhas = file.readlines()
    for linha in linhas:
        polinomio = []
        termo = linha.split("#")
        termo.remove("\n")
        for t in termo:
            monomio = t.split(",")
            monomio = (float(monomio[0]),int(monomio[1]))
            polinomio.append(monomio)
        for coeficiente,grau in polinomio:
            derivada = []
            if grau != 0:
                grau_der = grau - 1 
                derivada.append((coeficiente*grau, grau_der))                   
            else: 
                derivada.append((0,0))
    print (polinomio, "                            ", derivada)
    file.close()
    

#8
def somarPolinomios(p1,p2):
    soma = []
    i = 0
    j = 0
    while i < len(p1) and j < len(p2):
        c1, g1 = p1[i]
        c2, g2 = p2[j]
        if g1 == g2:
            soma.append((c1 + c2, g1))
            i = i + 1
            j = j + 1
        elif g1 > g2:
            soma.append((c1, g1))
            i = i + 1
        else:
            soma.append((c2, g2))
            j = j + 1
    while i < len(p1):
        c1, g1 = p1[i]
        soma.append((c2,g2))
        i = i + 1
    while j < len(p2):
        c2, g2 = p2[j]
        soma.append((c2, g2))
        j = j + 1

#9
import matplotlib.pyplot as plt
def grafico_polinomio(polinomio):
    abcissas = []
    ordenadas = []
    for x in range (0,10):
        abcissas.append(x)
        y = calc_Polinomio(polinomio,x)
        ordenadas.append(y)
    plt.plot(abcissas, ordenadas, color = "blue")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title("Gráfico do polinómio " + str(polinomio))
    plt.show()

menu = ("Menu\n0)Sair da aplicacao\n1)Criar um polinomio\n2)Ler uma lista de polinomios\n3)Listar polinomios\n4)Calcular o valor de um polinomio num ponto\n5)Listar polinomios com grau\n6)Polinomio de maior grau\n7)Derivada dos polinomios\n8)Somar dois polinomios\n9)Gerar um grafico para o polinomio\n")
opcao = input ("Insira uma opcao do menu")
print (menu)
while opcao != "0":
    if opcao == "1":
        Criar_Polinomio()
        print ("\n")
        opcao = input ("Insira uma opcao do menu")
    elif opcao == "2":
        Ler_Ficheiro("polinomios.txt")
        opcao = input ("Insira uma opcao do menu")
    elif opcao == "3":
        listarPolinomios ("polinomios.txt")
        print ("\n")
        opcao = input ("Insira uma opcao do menu")
    elif opcao == "4":
        polinomio = input ("Dos polinomios que existem, quer usar o polinomio de que ordem?")
        x = input ("Insira o valor de x para o qual quer obter o resultado do polinomio")
        print (calc_Polinomio(Ler_Ficheiro("polinomios.txt")[int(polinomio)-1], x))
        print ("\n")
        opcao = input ("Insira uma opcao do menu")
    elif opcao == "5":
        listarPolinomiosGrau("polinomios.txt")
        print ("\n")
        opcao = input ("Insira uma opcao do menu")
    elif opcao == "6":
        maior_grauPol("polinomios.txt")
        print ("\n")
        opcao = input ("Insira uma opcao do menu")
    elif opcao == "7":
        derivada_Polinomio("polinomios.txt")
        print ("\n")
        opcao = input ("Insira uma opcao do menu")
    elif opcao == "8":
        p1 = int(input("Que polinomio quer somar? Escreva a sua ordem"))
        p2 = int(input("Qual o outro polinomio para somar? Escreva a sua ordem"))
        somarPolinomios (Ler_Ficheiro("polinomios.txt")[(p1-1)], Ler_Ficheiro("Polinomios.txt")[(p2-1)])
        print ("\n")
        opcao = input ("Insira uma opcao do menu")
    elif opcao == "9":
        ordem = int(input("Qual a ordem do polinómio que quer usar?"))
        grafico_polinomio(Ler_Ficheiro("polinomios.txt")[(ordem-1)]) 
        opcao = input ("Insira uma opcao do menu")
print ("Saiu da aplicacao.")
# Out:
# Menu
# 0)Sair da aplicacao
# 1)Criar um polinomio
# 2)Ler uma lista de polinomios
# 3)Listar polinomios
# 4)Calcular o valor de um polinomio num ponto
# 5)Listar polinomios com grau
# 6)Polinomio de maior grau
# 7)Derivada dos polinomios
# 8)Somar dois polinomios
# 9)Gerar um grafico para o polinomio
#
# ___Ordem ___|______________ Polinomio_____________________
#      1      |    [(1.0, 7), (-3.7, 4), (5.0, 3), (88.0, 0)]
#      2      |    [(2.0, 2), (17.0, 0)]
#      3      |    [(7.0, 4), (6.0, 3), (-1.0, 2), (43.0, 0)]
#      4      |    [(1.0, 4)]
#      5      |    [(1.0, 2)]
#      6      |    [(1.0, 3)]
#
#
# __Ordem___|___Grau___|_________Polinómio__________________________
#     1     |     7    |    [(1.0, 7), (-3.7, 4), (5.0, 3), (88.0, 0)]
#     2     |     2    |    [(2.0, 2), (17.0, 0)]
#     3     |     4    |    [(7.0, 4), (6.0, 3), (-1.0, 2), (43.0, 0)]
#     4     |     4    |    [(1.0, 4)]
#     5     |     2    |    [(1.0, 2)]
# ...
